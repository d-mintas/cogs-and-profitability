# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import json

# %%
with open('newjson.json', 'r') as f:
    rjd = json.load(f)

# %%
ajd = rjd['RECORDS']

# %%
djd = pd.read_json(json.dumps(ajd), orient='records')

# %%
df = pd.DataFrame(data=djd[[0,1,4,6,12]])

# %%
df['totImps']=df['totInksPerTab']*df['qtyPerTab']

# %%
df['idx']=djd['tabID']

# %%
del df['gini']

# %%
del df['runtime']

# %%
df.set_index('idx', inplace=True, verify_integrity=True)

# %%
df['runtime']=djd['runTime']

# %%
df
# Out:
#         dopasPerTab  maxInksPerTab  qtyPerTab  totInksPerTab  totImps
# idx
# 68646             2              2         20              4       80
# 73435             2              4         93              5      465
# 74340             2              3         37              5      185
# 74498             2              2        100              4      400
# 74529             2              4         50              5      250
# 74708             1              1         50              1       50
# 74755             2              1        100              2      200
# 74787             1              1          6              1        6
# 74858             2              2        100              3      300
# 75013             1              2         59              2      118
# 75116             1              2         45              2       90
# 75135             2              1         50              2      100
# ...
