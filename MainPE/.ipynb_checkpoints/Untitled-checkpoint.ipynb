# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import json

# %%
sns.set()
# Out:
# /Users/Dino/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
with open('newjson.json', 'r') as f:
    rjd = json.load(f)

# %%
ajd = rjd['RECORDS']

# %%
djd = pd.read_json(json.dumps(ajd), orient='records')

# %%
df = djd

# %%
df
# Out:
#       dopasPerTab      gini   idx inkCntList  maxInksPerTab     oID  \
# 0               2  0.000000     0     [2, 2]              2  257399
# 1               2  0.300000     1     [4, 1]              4  261506
# 2               2  0.100000     2     [2, 3]              3  262287
# 3               2  0.000000     3     [2, 2]              2  262427
# 4               2  0.300000     4     [1, 4]              4  262456
# 5               1  0.000000     5        [1]              1  262604
# 6               2  0.000000     6     [1, 1]              1  262641
# 7               1  0.000000     7        [1]              1  262669
# 8               2  0.166667     8     [2, 1]              2  262730
# 9               1  0.000000     9        [2]              2  262865
# 10              1  0.000000    10        [2]              2  262955
# 11              2  0.000000    11     [1, 1]              1  262973
# 12              2  0.000000    12     [4, 4]              4  262983
# ...
